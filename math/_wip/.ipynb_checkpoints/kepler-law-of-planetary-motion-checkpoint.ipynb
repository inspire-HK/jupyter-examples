# %% [markdown]
# ## kepler law of planetary motion

# %%
from PIL import Image
from IPython.display import display

# %%
img = Image.open('orbital-period.png')
display(img)
# Algebra Page 328-329
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=750x1000>
